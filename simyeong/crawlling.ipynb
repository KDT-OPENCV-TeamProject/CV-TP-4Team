# %%
# import requests
# from bs4 import BeautifulSoup
# import os

# query = 'sm3'
# os.makedirs(query, exist_ok=True)
# path = '../data/' + query
# url = f'https://search.naver.com/search.naver?where=view&sm=tab_jum&query={query}'
# response = requests.get(url)
# soup = BeautifulSoup(response.content, "html.parser")

# links = soup.find_all("img")

# count = 0
# for a in links :
#     if '360도' in str(a):
#         print(str(a).split('"')[3])
#         # b = str(a).split('"')[3]
#         with open(query + str(count) + '.png', 'w', ) as F:
#             F.write(str(a).split('"')[3])
#     count +=1

# %%
import requests
from bs4 import BeautifulSoup
import os
# 현대 : '아이오닉5', '아이오닉6', '코나', '넥쏘', '더 뉴 아반떼', '쏘나타', '그랜저', '투싼', '싼타페', '스타리아'
# 르노 : 'xm3', 'qm6', 'qm3', 'sm6', '르노 마스터'
# 기아 : 'ev6', 'ev9'
# 제네시스 : '제네시스 g90', '제네시스 g70', '제네시스 gv70'
# 쉐보레 : '코란도', '토레스', '티볼리', '렉스턴'
# BMW : 'bmw ix', 'bmw i7', 'bmw i5', 'bmw i4', 'bmw ix3', 'bmw x7', 'bmw x6', 'bmw x5'
# 벤츠 : '벤츠 a클래스', '벤츠 s클래스', '벤츠 c클래스', '벤츠 glb', '벤츠 glc', '벤츠 gle', '벤츠 gls', '벤츠 g클래스'
# 아우디 : '아우디 e-tron', '아우디 a3', '아우디 a4', '아우디 a5', '아우디 a6', '아우디 a7', '아우디 a8', '아우디 q2', '아우디 q3', '아우디 q5', '아우디 q7', '아우디 q8']

queryList = ['xm3', 'qm6', 'qm3', 'qm5', 'sm6', '르노 마스터', '레이', '니로', '니로 플러스', 'ev6', 'ev9', '봉고', '제네시스 g90', '제니시스 g80', '제네시스 g70', '제네시스 gv80', '제네시스 gv70', '코란도', '토레스', '티볼리', '렉스턴', 'bmw ix', 'bmw i7', 'bmw i5', 'bmw i4', 'bmw ix3', 'bmw x7', 'bmw x6', 'bmw x5', '벤츠 a클래스', '벤츠 s클래스', '벤츠 c클래스', '벤츠 glb', '벤츠 glc', '벤츠 gle', '벤츠 gls', '벤츠 g클래스', '아우디 e-tron', '아우디 a3', '아우디 a4', '아우디 a5', '아우디 a6', '아우디 a7', '아우디 a8', '아우디 q2', '아우디 q3', '아우디 q5', '아우디 q7', '아우디 q8']

for query in queryList:
    a = os.makedirs(query, exist_ok=True)
    a
    path = '../'+ query
    url = f'https://search.naver.com/search.naver?where=view&sm=tab_jum&query={query}'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    links = soup.find_all("img")

    count = 0
    for a in links:
        if '360도' in str(a):
            thumb_url = str(a).split('"')[3]
            real_url = thumb_url.replace("_thumb", "")
            with open(f'./{query}/{query}_{count}.png', 'wb') as f:
                response = requests.get(real_url)
                f.write(response.content)
            count += 1
        print(f'{query} 끝')
# Out:
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# xm3 끝
# ...
